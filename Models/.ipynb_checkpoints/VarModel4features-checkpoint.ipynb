# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests, adfuller
from tqdm import tqdm_notebook
from itertools import product

import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
filepath = 'Data/processed_data.csv'

# %%
data = pd.read_csv(filepath)
data
# Out:
#            Date  NaturalGas   CrudeOil  HeatingOil  Consumption  Production  \
# 0    2001-01-01      7.4800  29.360001     0.84150      2676998     1753237
# 1    2001-02-01      5.5950  29.750000     0.77250      2309464     1582557
# 2    2001-03-01      5.2425  27.375000     0.72905      2246633     1766754
# 3    2001-04-01      5.1380  27.720000     0.75520      1807170     1703310
# 4    2001-05-01      4.2630  28.549999     0.77145      1522382     1763141
# ..          ...         ...        ...         ...          ...         ...
# 235  2020-08-01      2.3520  42.580002     1.24090      2401321     3011580
# 236  2020-09-01      2.3100  39.930000     1.11630      2171842     2917569
# 237  2020-10-01      2.8250  39.990000     1.15790      2320028     2991827
# 238  2020-11-01      2.8850  41.395000     1.24245      2434877     2984528
# 239  2020-12-01      2.5830  47.320000     1.46300      3167833     3088701
#
#      UndergroundStorage
# 0             5609446.0
# 1             5240820.0
# 2             5041971.0
# 3             5252851.0
# 4             5749464.0
# ..                  ...
# 235           7911918.0
# 236           8228769.0
# 237           8321354.0
# 238           8325457.0
# 239           7735441.0
#
# [240 rows x 7 columns]

# %%
macro_data = pd.read_csv(filepath, parse_dates=['Date'], index_col='Date')
print(macro_data.shape)
macro_data.head()
# Out:
# (240, 6)
#             NaturalGas   CrudeOil  HeatingOil  Consumption  Production  \
# Date
# 2001-01-01      7.4800  29.360001     0.84150      2676998     1753237
# 2001-02-01      5.5950  29.750000     0.77250      2309464     1582557
# 2001-03-01      5.2425  27.375000     0.72905      2246633     1766754
# 2001-04-01      5.1380  27.720000     0.75520      1807170     1703310
# 2001-05-01      4.2630  28.549999     0.77145      1522382     1763141
#
#             UndergroundStorage
# Date
# 2001-01-01           5609446.0
# 2001-02-01           5240820.0
# 2001-03-01           5041971.0
# 2001-04-01           5252851.0
# 2001-05-01           5749464.0

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = macro_data[macro_data.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(macro_data.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
ad_fuller_result_1 = adfuller(macro_data['NaturalGas'])#.diff()[1:])

print('realgdp')
print(f'ADF Statistic: {ad_fuller_result_1[0]}')
print(f'p-value: {ad_fuller_result_1[1]}')

print('\n---------------------\n')

ad_fuller_result_2 = adfuller(macro_data['CrudeOil'].diff()[1:])

print('realcons')
print(f'ADF Statistic: {ad_fuller_result_2[0]}')
print(f'p-value: {ad_fuller_result_2[1]}')
# Out:
# realgdp
# ADF Statistic: -1.5436759161366382
# p-value: 0.5118055891073908
#
# ---------------------
#
# realcons
# ADF Statistic: -10.740454388597588
# p-value: 2.8269600128988323e-19

# %%
print('prod causes ng?\n')
print('------------------')
granger_1 = grangercausalitytests(macro_data[['NaturalGas', 'CrudeOil']], 4)

print('\ng causes prod?\n')
print('------------------')
granger_2 = grangercausalitytests(macro_data[['CrudeOil', 'NaturalGas']], 4)
# Out:
# prod causes ng?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0546  , p=0.8155  , df_denom=236, df_num=1
# ssr based chi2 test:   chi2=0.0553  , p=0.8141  , df=1
# likelihood ratio test: chi2=0.0553  , p=0.8141  , df=1
# parameter F test:         F=0.0546  , p=0.8155  , df_denom=236, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0741  , p=0.9286  , df_denom=233, df_num=2
# ssr based chi2 test:   chi2=0.1513  , p=0.9271  , df=2
# likelihood ratio test: chi2=0.1512  , p=0.9272  , df=2
# parameter F test:         F=0.0741  , p=0.9286  , df_denom=233, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.3615  , p=0.0721  , df_denom=230, df_num=3
# ssr based chi2 test:   chi2=7.3002  , p=0.0629  , df=3
# likelihood ratio test: chi2=7.1900  , p=0.0661  , df=3
# parameter F test:         F=2.3615  , p=0.0721  , df_denom=230, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8833  , p=0.1142  , df_denom=227, df_num=4
# ssr based chi2 test:   chi2=7.8318  , p=0.0979  , df=4
# likelihood ratio test: chi2=7.7046  , p=0.1030  , df=4
# parameter F test:         F=1.8833  , p=0.1142  , df_denom=227, df_num=4
#
# g causes prod?
#
# ------------------
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2422  , p=0.6231  , df_denom=236, df_num=1
# ssr based chi2 test:   chi2=0.2453  , p=0.6204  , df=1
# likelihood ratio test: chi2=0.2451  , p=0.6205  , df=1
# parameter F test:         F=0.2422  , p=0.6231  , df_denom=236, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2547  , p=0.7753  , df_denom=233, df_num=2
# ssr based chi2 test:   chi2=0.5204  , p=0.7709  , df=2
# likelihood ratio test: chi2=0.5198  , p=0.7711  , df=2
# parameter F test:         F=0.2547  , p=0.7753  , df_denom=233, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1625  , p=0.9215  , df_denom=230, df_num=3
# ssr based chi2 test:   chi2=0.5024  , p=0.9184  , df=3
# likelihood ratio test: chi2=0.5019  , p=0.9185  , df=3
# parameter F test:         F=0.1625  , p=0.9215  , df_denom=230, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8063  , p=0.5222  , df_denom=227, df_num=4
# ssr based chi2 test:   chi2=3.3531  , p=0.5006  , df=4
# likelihood ratio test: chi2=3.3295  , p=0.5043  , df=4
# parameter F test:         F=0.8063  , p=0.5222  , df_denom=227, df_num=4

# %%
macro_data = macro_data[['NaturalGas','CrudeOil','Production','UndergroundStorage']]
print(macro_data.shape)
# Out:
# (240, 4)

# %%
train_df=macro_data[:-12]
test_df=macro_data[-12:]

# %%
print(test_df.shape)
# Out:
# (12, 4)

# %%
model = VAR(train_df.diff()[1:])

# %%
sorted_order=model.select_order(maxlags=20)
print(sorted_order.summary())
# Out:
#  VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0        51.73       51.80   2.933e+22       51.76
# 1        50.24       50.56   6.589e+21       50.37
# 2        49.43      50.01*   2.925e+21       49.66
# 3        49.48       50.32   3.080e+21       49.82
# 4        49.47       50.57   3.061e+21       49.91
# 5        49.16       50.51   2.246e+21       49.71
# 6        48.99       50.60   1.906e+21       49.65
# 7        48.73       50.60   1.467e+21       49.49
# 8        48.61       50.74   1.309e+21       49.47
# 9        48.62       51.00   1.325e+21       49.58
# 10       48.43       51.08   1.107e+21       49.50
# 11       47.97       50.87   7.033e+20       49.15
# 12       47.57       50.72   4.723e+20      48.84*
# 13      47.55*       50.97  4.696e+20*       48.93
# 14       47.63       51.30   5.146e+20       49.12
# 15       47.68       51.61   5.476e+20       49.27
# 16       47.72       51.91   5.797e+20       49.41
# 17       47.77       52.21   6.182e+20       49.56
# 18       47.85       52.55   6.822e+20       49.75
# 19       47.86       52.82   7.110e+20       49.87
# 20       47.94       53.15   7.867e+20       50.05
# --------------------------------------------------

# %%
var_model = VARMAX(train_df, order=(13,0),enforce_stationarity= True)
fitted_model = var_model.fit(disp=False)
print(fitted_model.summary())
# Out:
#                                                  Statespace Model Results
# ==========================================================================================================================
# Dep. Variable:     ['NaturalGas', 'CrudeOil', 'Production', 'UndergroundStorage']   No. Observations:                  228
# Model:                                                                    VAR(13)   Log Likelihood              -11097.461
#                                                                       + intercept   AIC                          22638.922
# Date:                                                            Mon, 28 Mar 2022   BIC                          23400.237
# Time:                                                                    22:10:44   HQIC                         22946.089
# Sample:                                                                01-01-2001
#                                                                      - 12-01-2019
# Covariance Type:                                                              opg
# =====================================================================================================
# Ljung-Box (L1) (Q):     170.50, 192.17, 111.31, 187.95   Jarque-Bera (JB):   652.00, 1.00, 0.68, 9.75
# Prob(Q):                        0.00, 0.00, 0.00, 0.00   Prob(JB):             0.00, 0.61, 0.71, 0.01
# Heteroskedasticity (H):         0.09, 0.82, 1.09, 1.38   Skew:               2.12, -0.03, 0.05, -0.47
# Prob(H) (two-sided):            0.00, 0.40, 0.72, 0.16   Kurtosis:            10.11, 2.68, 3.25, 2.65
#                              Results for equation NaturalGas
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# intercept                  4.6284   7.12e-05   6.51e+04      0.000       4.628       4.629
# L1.NaturalGas              0.0432      0.003     13.275      0.000       0.037       0.050
# L1.CrudeOil                0.0018      0.005      0.348      0.727      -0.008       0.012
# L1.Production           6.243e-07   5.91e-07      1.056      0.291   -5.35e-07    1.78e-06
# L1.UndergroundStorage    3.07e-08   2.59e-07      0.118      0.906   -4.78e-07    5.39e-07
# L2.NaturalGas              0.0379      0.004      9.895      0.000       0.030       0.045
# L2.CrudeOil                0.0021      0.007      0.301      0.763      -0.012       0.016
# L2.Production           4.342e-07   5.17e-07      0.839      0.401    -5.8e-07    1.45e-06
# L2.UndergroundStorage  -3.882e-08   3.97e-07     -0.098      0.922   -8.17e-07    7.39e-07
# L3.NaturalGas              0.0321      0.003     10.414      0.000       0.026       0.038
# L3.CrudeOil                0.0021      0.007      0.291      0.771      -0.012       0.016
# L3.Production           2.761e-07   4.48e-07      0.616      0.538   -6.02e-07    1.15e-06
# L3.UndergroundStorage  -5.763e-08   3.74e-07     -0.154      0.878   -7.92e-07    6.76e-07
# L4.NaturalGas              0.0300      0.003     11.545      0.000       0.025       0.035
# L4.CrudeOil                0.0019      0.006      0.298      0.766      -0.010       0.014
# L4.Production           1.073e-07   4.47e-07      0.240      0.810   -7.69e-07    9.83e-07
# L4.UndergroundStorage  -3.518e-08   3.75e-07     -0.094      0.925    -7.7e-07    6.99e-07
# L5.NaturalGas              0.0300      0.003     10.466      0.000       0.024       0.036
# L5.CrudeOil                0.0016      0.006      0.274      0.784      -0.010       0.013
# L5.Production          -1.135e-08   5.53e-07     -0.021      0.984    -1.1e-06    1.07e-06
# L5.UndergroundStorage   3.095e-08   4.21e-07      0.073      0.941   -7.95e-07    8.57e-07
# L6.NaturalGas              0.0317      0.003     12.353      0.000       0.027       0.037
# L6.CrudeOil                0.0010      0.007      0.147      0.883      -0.012       0.014
# L6.Production          -1.176e-07   5.47e-07     -0.215      0.830   -1.19e-06    9.54e-07
# L6.UndergroundStorage   1.043e-07   4.73e-07      0.220      0.826   -8.23e-07    1.03e-06
# L7.NaturalGas              0.0274      0.003     10.009      0.000       0.022       0.033
# L7.CrudeOil                0.0003      0.007      0.037      0.970      -0.013       0.014
# ==========================================================================================================
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# sqrt.var.NaturalGas                        0.6947      0.004    158.290      0.000       0.686       0.703
# sqrt.cov.NaturalGas.CrudeOil               1.6143      0.000   4572.881      0.000       1.614       1.615
# sqrt.var.CrudeOil                          5.2679      0.001   5530.789      0.000       5.266       5.270
# sqrt.cov.NaturalGas.Production         -6766.4989        nan        nan        nan         nan         nan
# sqrt.cov.CrudeOil.Production            2034.5887   1.24e-07   1.65e+10      0.000    2034.589    2034.589
# sqrt.var.Production                         4e+04        nan        nan        nan         nan         nan
# sqrt.cov.NaturalGas.UndergroundStorage -3.738e+04   1.43e-08  -2.62e+12      0.000   -3.74e+04   -3.74e+04
# sqrt.cov.CrudeOil.UndergroundStorage    6396.3238   1.56e-08    4.1e+11      0.000    6396.324    6396.324
# sqrt.cov.Production.UndergroundStorage  -655.7440   2.51e-07  -2.62e+09      0.000    -655.744    -655.744
# sqrt.var.UndergroundStorage              9.15e+04        nan        nan        nan         nan         nan
# ==========================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.58e+27. Standard errors may be unstable.

# %%
n_forecast = 12
predict = fitted_model.get_prediction(start=len(train_df),end=len(train_df) + n_forecast-1)#start="1989-07-01",end='1999-01-01')

predictions=predict.predicted_mean

# %%
predictions.columns=['ng_predicted','co_predicted','prod_predicted','us_predicted']
predictions
# Out:
#             ng_predicted  co_predicted  prod_predicted  us_predicted
# 2020-01-01      2.035006     42.527866    2.908065e+06  7.159918e+06
# 2020-02-01      1.802235     42.461304    2.912224e+06  6.812074e+06
# 2020-03-01      1.655255     42.863597    2.941139e+06  6.638284e+06
# 2020-04-01      1.456607     41.986928    2.977856e+06  6.680021e+06
# 2020-05-01      1.468785     41.875817    2.997106e+06  6.810942e+06
# 2020-06-01      1.393071     40.650007    3.005205e+06  7.001361e+06
# 2020-07-01      1.299057     39.519006    3.019836e+06  7.242120e+06
# 2020-08-01      1.092195     38.152248    3.032980e+06  7.555625e+06
# 2020-09-01      1.017332     36.599486    3.026118e+06  7.847267e+06
# 2020-10-01      1.024663     35.236956    3.009063e+06  8.016797e+06
# 2020-11-01      1.024093     33.379511    2.981997e+06  7.998757e+06
# 2020-12-01      1.066909     32.423572    2.945951e+06  7.799825e+06

# %%
test_vs_pred=pd.concat([test_df,predictions],axis=1)

# %%
test_vs_pred.plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error
import math 
from statistics import mean

rmse_ulc=math.sqrt(mean_squared_error(predictions['ng_predicted'],test_df['NaturalGas']))
print('Mean value of NG is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['NaturalGas']),rmse_ulc))

rmse_rgnp=math.sqrt(mean_squared_error(predictions['co_predicted'],test_df['CrudeOil']))
print('Mean value of CO is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['CrudeOil']),rmse_rgnp))

rmse_rgnp=math.sqrt(mean_squared_error(predictions['prod_predicted'],test_df['Production']))
print('Mean value of PR is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['Production']),rmse_rgnp))

rmse_rgnp=math.sqrt(mean_squared_error(predictions['us_predicted'],test_df['UndergroundStorage']))
print('Mean value of US is : {}. Root Mean Squared Error is :{}'.format(mean(test_df['UndergroundStorage']),rmse_rgnp))
# Out:
# Mean value of NG is : 2.137833322087924. Root Mean Squared Error is :1.033117821254525
# Mean value of CO is : 39.62666710217794. Root Mean Squared Error is :11.384803244261265
# Mean value of PR is : 3016870.4166666665. Root Mean Squared Error is :131859.0902797963
# Mean value of CO is : 7456273.166666667. Root Mean Squared Error is :325610.53556207614

# %%
nggas = pd.concat([test_vs_pred["NaturalGas"],test_vs_pred["ng_predicted"]],axis=1)

# %%
nggas.plot()
# Out:
# <AxesSubplot:>
